-- %%
CREATE OR REPLACE TABLE eatery_group.silver.restaurant_quarantine AS
SELECT *
FROM eatery_group.silver.restaurant_validation
WHERE 
  invalid_id = 1
  OR invalid_name = 1
  OR invalid_city = 1
  OR invalid_cuisines = 1
  OR invalid_latitude = 1
  OR invalid_longitude = 1
  OR invalid_cost = 1
  OR invalid_votes = 1
  OR invalid_rating = 1;

   SELECT *
   FROM eatery_group.silver.restaurant_quarantine
